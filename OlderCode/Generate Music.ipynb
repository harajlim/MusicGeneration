# %% [markdown]
# import sys
# !{sys.executable} -m pip install music21
# !{sys.executable} -m pip install tqdm

# %%
import music21
import numpy as np
import glob
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import pandas as pd
from keras.utils import np_utils
from collections import defaultdict

from keras.models import Sequential
from keras.layers import Activation, Dense, LSTM, Dropout, Flatten
# Out:
# C:\Users\MHarajli\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
with open('encodings/information.pickle','rb') as file:
    DF=pickle.load(file)

# %%
DF=DF[DF['Artist']=='chopin']

# %%
DF=DF.iloc[[0,1,2,3],:]

# %%
with open('SavedModels/vocab.pickle','rb') as file:
    vocab=pickle.load(file)
    
with open('SavedModels/WordToNumber.pickle','rb') as file:
    WordToNumber=pickle.load(file)

with open('SavedModels/NumberToWord.pickle','rb') as file:
    NumberToWord=pickle.load(file)
    
with open('SavedModels/GfToNumber.pickle','rb') as file:
    GfToNumber=pickle.load(file)
with open('SavedModels/NumberToGf.pickle','rb') as file:
    NumberToGf=pickle.load(file)
    
with open('SavedModels/NoteToNumber.pickle','rb') as file:
    NoteToNumber=pickle.load(file)
    
with open('SavedModels/NumberToNote.pickle','rb') as file:
    NumberToNote=pickle.load(file)

# %%
def prepare_sequences_gf_or_note(DF, n_vocab,WordToNumber,sequence_length=100): 
    """Given a list of locations for all the midi files in the dataset, this function encodes each song"""
    # Extract the unique pitches in the list of notes.

    network_input = []
    network_output = []
    for i in tqdm(range(len(DF))):
        song=DF.iloc[i,2]
        # create input sequences and the corresponding outputs
        
        for i in range(0, len(song) - sequence_length, 1):
            #we only use the sequence if the last event is not a gf event:
            sequence_in = song[i: i + sequence_length]
            if 'gf' not in str(sequence_in[-1]):
                sequence_out = float('gf' in str(song[i + sequence_length]))
                network_input.append([WordToNumber[char] for char in sequence_in])
                network_output.append(sequence_out)
                

    n_patterns = len(network_input)
    
    # reshape the input into a format comatible with LSTM layers 
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input
    network_input = network_input / float(n_vocab)
    
    # one hot encode the output vectors
    network_output = np_utils.to_categorical(network_output)
    
    return (network_input, network_output)

# %%
def prepare_sequences_get_gf(DF, n_vocab,WordToNumber,GfToNumber,sequence_length=100): 
    """Given a list of locations for all the midi files in the dataset, this function encodes each song"""
    # Extract the unique pitches in the list of notes.

    network_input = []
    network_output = []
    for i in tqdm(range(len(DF))):
        song=DF.iloc[i,2]
        # create input sequences and the corresponding outputs
        
        for i in range(0, len(song) - sequence_length, 1):
            #we only use the sequence if the last event is not a gf event:
            sequence_in = song[i: i + sequence_length]
            sequence_out=song[i + sequence_length]
            if 'gf' in str(sequence_out):
                network_input.append([WordToNumber[char] for char in sequence_in])
                network_output.append(GfToNumber[sequence_out])
                

    n_patterns = len(network_input)
    
    # reshape the input into a format comatible with LSTM layers 
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input
    network_input = network_input / float(n_vocab)
    
    # one hot encode the output vectors
    network_output = np_utils.to_categorical(network_output)
    
    return (network_input, network_output)

# %%
def prepare_sequences_get_note(DF, n_vocab,WordToNumber,NoteToNumber,sequence_length=100): 
    """Given a list of locations for all the midi files in the dataset, this function encodes each song"""
    # Extract the unique pitches in the list of notes.

    network_input = []
    network_output = []
    for i in tqdm(range(len(DF))):
        song=DF.iloc[i,2]
        # create input sequences and the corresponding outputs
        
        for i in range(0, len(song) - sequence_length, 1):
            #we only use the sequence if the last event is not a gf event:
            sequence_in = song[i: i + sequence_length]
            sequence_out=song[i + sequence_length]
            if 'gf' not in str(sequence_out):
                network_input.append([WordToNumber[char] for char in sequence_in])
                network_output.append(NoteToNumber[sequence_out])
                

    n_patterns = len(network_input)
    
    # reshape the input into a format comatible with LSTM layers 
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input
    network_input = network_input / float(n_vocab)
    
    # one hot encode the output vectors
    network_output = np_utils.to_categorical(network_output)
    
    return (network_input, network_output)

# %%
def create_network_gf_or_note(network_in, n_vocab_out): 
    """Create the model architecture"""
    model = Sequential()
    model.add(LSTM(20, input_shape=network_in.shape[1:], return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(20,return_sequences=True))
    model.add(Flatten())
    model.add(Dense(20))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab_out))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

    return model

# %%
def create_network_get_gf(network_in, n_vocab_out): 
    """Create the model architecture"""
    model = Sequential()
    model.add(LSTM(20, input_shape=network_in.shape[1:], return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(20,return_sequences=True))
    model.add(Flatten())
    model.add(Dense(20))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab_out))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

    return model

# %%
def create_network_get_note(network_in, n_vocab_out): 
    """Create the model architecture"""
    model = Sequential()
    model.add(LSTM(20, input_shape=network_in.shape[1:], return_sequences=True))
    model.add(Dropout(0.3))
    model.add(LSTM(20,return_sequences=True))
    model.add(Flatten())
    model.add(Dense(20))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab_out))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

    return model

# %%
#we first need to load the trained models:

#gf_or_note_input,gf_or_note_output=prepare_sequences_gf_or_note(DF,len(WordToNumber),WordToNumber)
#get_gf_input,get_gf_output=prepare_sequences_get_gf(DF,len(WordToNumber),WordToNumber,GfToNumber)
#get_note_input,get_note_output=prepare_sequences_get_note(DF,len(WordToNumber),WordToNumber,NoteToNumber)

from keras.models import load_model
get_gf = load_model('SavedModels/weights.get_gf.hdf5')

gf_or_note = load_model('SavedModels/weights.gf_or_note.hdf5')

get_note = load_model('SavedModels/weights.get_note.hdf5')

# %%
#now we have all three models. We start with a sequence:
#We pick the beggining of the first song in our DF: chpn-p1:
encoding=DF.iloc[3,2]
sequenceIn=[]

for word in encoding[:100]:
    sequenceIn.append(WordToNumber[word])
FullSequence=sequenceIn

for i in range(300):
    if 'gf' in str(NumberToWord[sequenceIn[-1]]):
        
        next_note=get_note.predict(np.reshape(sequenceIn,(1,100,1))/len(vocab))
        next_note=np.argmax(next_note)
        next_note=NumberToNote[next_note]
        next_note=WordToNumber[next_note]
        FullSequence.append(next_note)
    else:
        
        nextStep=gf_or_note.predict(np.reshape(sequenceIn,(1,100,1))/len(vocab))
        nextStep=np.argmax(nextStep)
        
        #we get nextStep=1 if next step is a gf and 0 if note
        if nextStep==0:
            next_note=get_note.predict(np.reshape(sequenceIn,(1,100,1))/len(vocab))
            next_note=np.argmax(next_note)
            next_note=NumberToNote[next_note]
            next_note=WordToNumber[next_note]
            FullSequence.append(next_note)
        else:
            next_gf=get_gf.predict(np.reshape(sequenceIn,(1,100,1))/len(vocab))
            next_gf=np.argmax(next_gf)
            next_gf=NumberToGf[next_gf]
            
            next_gf=WordToNumber[next_gf]
            FullSequence.append(next_gf)
    sequenceIn=FullSequence[-100:]
            
Composition=[]            
for number in FullSequence:
    Composition.append(NumberToWord[number])

# %%
#next we write a function that takes in a sequence of events and changes it into a midi file:
def write_midi(composition,filename):
    MidiSequence=[]
    Offset=0
    for word in composition:
        if 'gf' in str(word):
            Offset+=float(word[2:])
        else:
            new_note=music21.note.Note(int(word))
            new_note.offset=Offset
            new_note.storedInstrument=music21.instrument.Piano()
            MidiSequence.append(new_note)
            
    midi_stream=music21.stream.Stream(MidiSequence)
    midi_stream.write('midi', fp=filename)    
    
    return 1

# %%
write_midi(Composition,'Samples/ChopinOnly.mid')
# Out:
# 1

# %%
for i in range(len(Composition)):
    if encoding[i]==Composition[i]:
        print('Song Goes: '+str(encoding[i])+' and we guess: '+str(Composition[i])+' at index: '+str(i))
    else:
        print('Song Goes: '+str(encoding[i])+' and we guess: '+str(Composition[i])+' at index: '+str(i)+'<---------')
# Out:
# Song Goes: 36 and we guess: 36 at index: 0
# Song Goes: gf0.25 and we guess: gf0.25 at index: 1
# Song Goes: 43 and we guess: 43 at index: 2
# Song Goes: 55 and we guess: 55 at index: 3
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 4
# Song Goes: 52 and we guess: 52 at index: 5
# Song Goes: 60 and we guess: 60 at index: 6
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 7
# Song Goes: 64 and we guess: 64 at index: 8
# Song Goes: 67 and we guess: 67 at index: 9
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 10
# Song Goes: 60 and we guess: 60 at index: 11
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 12
# Song Goes: 57 and we guess: 57 at index: 13
# Song Goes: 69 and we guess: 69 at index: 14
# Song Goes: gf0.25 and we guess: gf0.25 at index: 15
# Song Goes: 35 and we guess: 35 at index: 16
# Song Goes: gf0.25 and we guess: gf0.25 at index: 17
# Song Goes: 43 and we guess: 43 at index: 18
# Song Goes: 55 and we guess: 55 at index: 19
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 20
# Song Goes: 53 and we guess: 53 at index: 21
# Song Goes: 62 and we guess: 62 at index: 22
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 23
# Song Goes: 65 and we guess: 65 at index: 24
# Song Goes: 67 and we guess: 67 at index: 25
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 26
# Song Goes: 62 and we guess: 62 at index: 27
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 28
# Song Goes: 57 and we guess: 57 at index: 29
# Song Goes: 69 and we guess: 69 at index: 30
# Song Goes: gf0.25 and we guess: gf0.25 at index: 31
# Song Goes: 36 and we guess: 36 at index: 32
# Song Goes: gf0.25 and we guess: gf0.25 at index: 33
# Song Goes: 43 and we guess: 43 at index: 34
# Song Goes: 55 and we guess: 55 at index: 35
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 36
# Song Goes: 52 and we guess: 52 at index: 37
# Song Goes: 60 and we guess: 60 at index: 38
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 39
# Song Goes: 64 and we guess: 64 at index: 40
# Song Goes: 67 and we guess: 67 at index: 41
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 42
# Song Goes: 60 and we guess: 60 at index: 43
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 44
# Song Goes: 57 and we guess: 57 at index: 45
# Song Goes: 69 and we guess: 69 at index: 46
# Song Goes: gf0.25 and we guess: gf0.25 at index: 47
# Song Goes: 40 and we guess: 40 at index: 48
# Song Goes: gf0.25 and we guess: gf0.25 at index: 49
# Song Goes: 52 and we guess: 52 at index: 50
# Song Goes: 59 and we guess: 59 at index: 51
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 52
# Song Goes: 55 and we guess: 55 at index: 53
# Song Goes: 64 and we guess: 64 at index: 54
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 55
# Song Goes: 67 and we guess: 67 at index: 56
# Song Goes: 71 and we guess: 71 at index: 57
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 58
# Song Goes: 64 and we guess: 64 at index: 59
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 60
# Song Goes: 60 and we guess: 60 at index: 61
# Song Goes: 72 and we guess: 72 at index: 62
# Song Goes: gf0.25 and we guess: gf0.25 at index: 63
# Song Goes: 41 and we guess: 41 at index: 64
# Song Goes: gf0.25 and we guess: gf0.25 at index: 65
# Song Goes: 52 and we guess: 52 at index: 66
# Song Goes: 64 and we guess: 64 at index: 67
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 68
# Song Goes: 57 and we guess: 57 at index: 69
# Song Goes: 69 and we guess: 69 at index: 70
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 71
# Song Goes: 72 and we guess: 72 at index: 72
# Song Goes: 76 and we guess: 76 at index: 73
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 74
# Song Goes: 69 and we guess: 69 at index: 75
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 76
# Song Goes: 62 and we guess: 62 at index: 77
# Song Goes: 74 and we guess: 74 at index: 78
# Song Goes: gf0.25 and we guess: gf0.25 at index: 79
# Song Goes: 42 and we guess: 42 at index: 80
# Song Goes: gf0.25 and we guess: gf0.25 at index: 81
# Song Goes: 50 and we guess: 50 at index: 82
# Song Goes: 64 and we guess: 64 at index: 83
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 84
# Song Goes: 60 and we guess: 60 at index: 85
# Song Goes: 69 and we guess: 69 at index: 86
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 87
# Song Goes: 72 and we guess: 72 at index: 88
# Song Goes: 76 and we guess: 76 at index: 89
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 90
# Song Goes: 69 and we guess: 69 at index: 91
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 92
# Song Goes: 62 and we guess: 62 at index: 93
# Song Goes: 74 and we guess: 74 at index: 94
# Song Goes: gf0.25 and we guess: gf0.25 at index: 95
# Song Goes: 43 and we guess: 43 at index: 96
# Song Goes: gf0.25 and we guess: gf0.25 at index: 97
# Song Goes: 53 and we guess: 53 at index: 98
# Song Goes: 64 and we guess: 64 at index: 99
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 100
# Song Goes: 59 and we guess: 60 at index: 101<---------
# Song Goes: 67 and we guess: 67 at index: 102
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 103
# Song Goes: 71 and we guess: 72 at index: 104<---------
# Song Goes: 76 and we guess: 76 at index: 105
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 106
# Song Goes: 67 and we guess: 67 at index: 107
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 108
# Song Goes: 62 and we guess: 64 at index: 109<---------
# Song Goes: 74 and we guess: 74 at index: 110
# Song Goes: gf0.25 and we guess: gf0.25 at index: 111
# Song Goes: 31 and we guess: 31 at index: 112
# Song Goes: gf0.25 and we guess: 43 at index: 113<---------
# Song Goes: 43 and we guess: gf0.25 at index: 114<---------
# Song Goes: 59 and we guess: 64 at index: 115<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 116
# Song Goes: 53 and we guess: 60 at index: 117<---------
# Song Goes: 62 and we guess: 62 at index: 118
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 119
# Song Goes: 65 and we guess: 72 at index: 120<---------
# Song Goes: 71 and we guess: 75 at index: 121<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 122
# Song Goes: 62 and we guess: 62 at index: 123
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 124
# Song Goes: 57 and we guess: 57 at index: 125
# Song Goes: 69 and we guess: 69 at index: 126
# Song Goes: gf0.25 and we guess: gf0.25 at index: 127
# Song Goes: 36 and we guess: 36 at index: 128
# Song Goes: gf0.25 and we guess: gf0.25 at index: 129
# Song Goes: 43 and we guess: 43 at index: 130
# Song Goes: 55 and we guess: 55 at index: 131
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 132
# Song Goes: 52 and we guess: 52 at index: 133
# Song Goes: 60 and we guess: 60 at index: 134
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 135
# Song Goes: 64 and we guess: 64 at index: 136
# Song Goes: 67 and we guess: 67 at index: 137
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 138
# Song Goes: 60 and we guess: 60 at index: 139
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 140
# Song Goes: 57 and we guess: 57 at index: 141
# Song Goes: 69 and we guess: 69 at index: 142
# Song Goes: gf0.25 and we guess: gf0.25 at index: 143
# Song Goes: 35 and we guess: 36 at index: 144<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 145
# Song Goes: 43 and we guess: 43 at index: 146
# Song Goes: 55 and we guess: 55 at index: 147
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 148
# Song Goes: 53 and we guess: 53 at index: 149
# Song Goes: 62 and we guess: 62 at index: 150
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 151
# Song Goes: 65 and we guess: 65 at index: 152
# Song Goes: 67 and we guess: 67 at index: 153
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 154
# Song Goes: 62 and we guess: 62 at index: 155
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 156
# Song Goes: 57 and we guess: 57 at index: 157
# Song Goes: 69 and we guess: 69 at index: 158
# Song Goes: gf0.25 and we guess: gf0.25 at index: 159
# Song Goes: 36 and we guess: 36 at index: 160
# Song Goes: gf0.25 and we guess: gf0.25 at index: 161
# Song Goes: 43 and we guess: 43 at index: 162
# Song Goes: 55 and we guess: 55 at index: 163
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 164
# Song Goes: 52 and we guess: 52 at index: 165
# Song Goes: 60 and we guess: 60 at index: 166
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 167
# Song Goes: 64 and we guess: 64 at index: 168
# Song Goes: 67 and we guess: 67 at index: 169
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 170
# Song Goes: 60 and we guess: 60 at index: 171
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 172
# Song Goes: 57 and we guess: 57 at index: 173
# Song Goes: 69 and we guess: 69 at index: 174
# Song Goes: gf0.25 and we guess: gf0.25 at index: 175
# Song Goes: 40 and we guess: 40 at index: 176
# Song Goes: gf0.25 and we guess: gf0.25 at index: 177
# Song Goes: 52 and we guess: 43 at index: 178<---------
# Song Goes: 59 and we guess: 55 at index: 179<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 180
# Song Goes: 55 and we guess: 60 at index: 181<---------
# Song Goes: 64 and we guess: 60 at index: 182<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 183
# Song Goes: 67 and we guess: 71 at index: 184<---------
# Song Goes: 71 and we guess: 67 at index: 185<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 186
# Song Goes: 64 and we guess: 64 at index: 187
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 188
# Song Goes: 60 and we guess: 57 at index: 189<---------
# Song Goes: 72 and we guess: 72 at index: 190
# Song Goes: gf0.25 and we guess: gf0.25 at index: 191
# Song Goes: 41 and we guess: 41 at index: 192
# Song Goes: gf0.25 and we guess: gf0.25 at index: 193
# Song Goes: 48 and we guess: 52 at index: 194<---------
# Song Goes: 61 and we guess: 59 at index: 195<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 196
# Song Goes: 57 and we guess: 55 at index: 197<---------
# Song Goes: 65 and we guess: 65 at index: 198
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 199
# Song Goes: 69 and we guess: 69 at index: 200
# Song Goes: 73 and we guess: 73 at index: 201
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 202
# Song Goes: 65 and we guess: 65 at index: 203
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 204
# Song Goes: 62 and we guess: 62 at index: 205
# Song Goes: 74 and we guess: 74 at index: 206
# Song Goes: gf0.25 and we guess: gf0.25 at index: 207
# Song Goes: 43 and we guess: 43 at index: 208
# Song Goes: gf0.25 and we guess: gf0.25 at index: 209
# Song Goes: 48 and we guess: 48 at index: 210
# Song Goes: 63 and we guess: 61 at index: 211<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 212
# Song Goes: 58 and we guess: 57 at index: 213<---------
# Song Goes: 67 and we guess: 65 at index: 214<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 215
# Song Goes: 72 and we guess: 72 at index: 216
# Song Goes: 75 and we guess: 72 at index: 217<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 218
# Song Goes: 67 and we guess: 65 at index: 219<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 220
# Song Goes: 64 and we guess: 62 at index: 221<---------
# Song Goes: 76 and we guess: 76 at index: 222
# Song Goes: gf0.25 and we guess: gf0.25 at index: 223
# Song Goes: 45 and we guess: 45 at index: 224
# Song Goes: gf0.25 and we guess: gf0.25 at index: 225
# Song Goes: 53 and we guess: 43 at index: 226<---------
# Song Goes: 67 and we guess: 63 at index: 227<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 228
# Song Goes: 60 and we guess: 59 at index: 229<---------
# Song Goes: 69 and we guess: 67 at index: 230<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 231
# Song Goes: 72 and we guess: 72 at index: 232
# Song Goes: 79 and we guess: 76 at index: 233<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 234
# Song Goes: 69 and we guess: 67 at index: 235<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 236
# Song Goes: 65 and we guess: 64 at index: 237<---------
# Song Goes: 77 and we guess: 76 at index: 238<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 239
# Song Goes: 43 and we guess: 45 at index: 240<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 241
# Song Goes: 48 and we guess: 43 at index: 242<---------
# Song Goes: 63 and we guess: 63 at index: 243
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 244
# Song Goes: 60 and we guess: 60 at index: 245
# Song Goes: 67 and we guess: 67 at index: 246
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 247
# Song Goes: 72 and we guess: 72 at index: 248
# Song Goes: 75 and we guess: 75 at index: 249
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 250
# Song Goes: 67 and we guess: 67 at index: 251
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 252
# Song Goes: 64 and we guess: 64 at index: 253
# Song Goes: 76 and we guess: 76 at index: 254
# Song Goes: gf0.25 and we guess: gf0.25 at index: 255
# Song Goes: 45 and we guess: 36 at index: 256<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 257
# Song Goes: 53 and we guess: 43 at index: 258<---------
# Song Goes: 64 and we guess: 64 at index: 259
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 260
# Song Goes: 60 and we guess: 60 at index: 261
# Song Goes: 69 and we guess: 62 at index: 262<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 263
# Song Goes: 72 and we guess: 72 at index: 264
# Song Goes: 76 and we guess: 75 at index: 265<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 266
# Song Goes: 69 and we guess: 69 at index: 267
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 268
# Song Goes: 65 and we guess: 65 at index: 269
# Song Goes: 77 and we guess: 69 at index: 270<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 271
# Song Goes: 47 and we guess: 36 at index: 272<---------
# Song Goes: 66 and we guess: gf0.25 at index: 273<---------
# Song Goes: gf0.25 and we guess: 43 at index: 274<---------
# Song Goes: 55 and we guess: 55 at index: 275
# Song Goes: 71 and we guess: gf0.0833 at index: 276<---------
# Song Goes: gf0.0833 and we guess: 60 at index: 277<---------
# Song Goes: 62 and we guess: 60 at index: 278<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 279
# Song Goes: 74 and we guess: 65 at index: 280<---------
# Song Goes: 78 and we guess: 75 at index: 281<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 282
# Song Goes: 71 and we guess: 62 at index: 283<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 284
# Song Goes: 67 and we guess: 57 at index: 285<---------
# Song Goes: 79 and we guess: 69 at index: 286<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 287
# Song Goes: 48 and we guess: 36 at index: 288<---------
# Song Goes: 68 and we guess: gf0.25 at index: 289<---------
# Song Goes: gf0.25 and we guess: 43 at index: 290<---------
# Song Goes: 55 and we guess: 55 at index: 291
# Song Goes: 72 and we guess: gf0.0833 at index: 292<---------
# Song Goes: gf0.0833 and we guess: 60 at index: 293<---------
# Song Goes: 64 and we guess: 64 at index: 294
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 295
# Song Goes: 76 and we guess: 65 at index: 296<---------
# Song Goes: 80 and we guess: 67 at index: 297<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 298
# Song Goes: 72 and we guess: 60 at index: 299<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 300
# Song Goes: 69 and we guess: 57 at index: 301<---------
# Song Goes: 81 and we guess: 69 at index: 302<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 303
# Song Goes: 50 and we guess: 36 at index: 304<---------
# Song Goes: 70 and we guess: gf0.25 at index: 305<---------
# Song Goes: gf0.25 and we guess: 43 at index: 306<---------
# Song Goes: 55 and we guess: 55 at index: 307
# Song Goes: 74 and we guess: gf0.0833 at index: 308<---------
# Song Goes: gf0.0833 and we guess: 52 at index: 309<---------
# Song Goes: 65 and we guess: 60 at index: 310<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 311
# Song Goes: 79 and we guess: 65 at index: 312<---------
# Song Goes: 82 and we guess: 67 at index: 313<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 314
# Song Goes: 74 and we guess: 60 at index: 315<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 316
# Song Goes: 71 and we guess: 57 at index: 317<---------
# Song Goes: 83 and we guess: 69 at index: 318<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 319
# Song Goes: 52 and we guess: 36 at index: 320<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 321
# Song Goes: 60 and we guess: 43 at index: 322<---------
# Song Goes: 74 and we guess: 55 at index: 323<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 324
# Song Goes: 67 and we guess: 55 at index: 325<---------
# Song Goes: 76 and we guess: 60 at index: 326<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 327
# Song Goes: 79 and we guess: 64 at index: 328<---------
# Song Goes: 86 and we guess: 67 at index: 329<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 330
# Song Goes: 76 and we guess: 64 at index: 331<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 332
# Song Goes: 72 and we guess: 57 at index: 333<---------
# Song Goes: 84 and we guess: 69 at index: 334<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 335
# Song Goes: 42 and we guess: 36 at index: 336<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 337
# Song Goes: 51 and we guess: 43 at index: 338<---------
# Song Goes: 71 and we guess: 60 at index: 339<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 340
# Song Goes: 60 and we guess: 55 at index: 341<---------
# Song Goes: 72 and we guess: 60 at index: 342<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 343
# Song Goes: 75 and we guess: 64 at index: 344<---------
# Song Goes: 83 and we guess: 67 at index: 345<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 346
# Song Goes: 72 and we guess: 64 at index: 347<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 348
# Song Goes: 69 and we guess: 60 at index: 349<---------
# Song Goes: 81 and we guess: 69 at index: 350<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 351
# Song Goes: 43 and we guess: 36 at index: 352<---------
# Song Goes: 69 and we guess: gf0.25 at index: 353<---------
# Song Goes: gf0.25 and we guess: 43 at index: 354<---------
# Song Goes: 52 and we guess: 59 at index: 355<---------
# Song Goes: 72 and we guess: gf0.0833 at index: 356<---------
# Song Goes: gf0.0833 and we guess: 57 at index: 357<---------
# Song Goes: 60 and we guess: 65 at index: 358<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 359
# Song Goes: 76 and we guess: 69 at index: 360<---------
# Song Goes: 81 and we guess: 73 at index: 361<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 362
# Song Goes: 72 and we guess: 65 at index: 363<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 364
# Song Goes: 67 and we guess: 64 at index: 365<---------
# Song Goes: 79 and we guess: 74 at index: 366<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 367
# Song Goes: 43 and we guess: 43 at index: 368
# Song Goes: gf0.25 and we guess: gf0.25 at index: 369
# Song Goes: 53 and we guess: 48 at index: 370<---------
# Song Goes: 64 and we guess: 59 at index: 371<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 372
# Song Goes: 59 and we guess: 58 at index: 373<---------
# Song Goes: 67 and we guess: 69 at index: 374<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 375
# Song Goes: 71 and we guess: 72 at index: 376<---------
# Song Goes: 76 and we guess: 72 at index: 377<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 378
# Song Goes: 67 and we guess: 67 at index: 379
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 380
# Song Goes: 62 and we guess: 62 at index: 381
# Song Goes: 74 and we guess: 76 at index: 382<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 383
# Song Goes: 36 and we guess: 45 at index: 384<---------
# Song Goes: 55 and we guess: gf0.25 at index: 385<---------
# Song Goes: gf0.25 and we guess: 48 at index: 386<---------
# Song Goes: 43 and we guess: 63 at index: 387<---------
# Song Goes: 60 and we guess: gf0.0833 at index: 388<---------
# Song Goes: gf0.0833 and we guess: 60 at index: 389<---------
# Song Goes: 52 and we guess: 67 at index: 390<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 391
# Song Goes: 64 and we guess: 72 at index: 392<---------
# Song Goes: 67 and we guess: 72 at index: 393<---------
# Song Goes: gf0.1667 and we guess: gf0.1667 at index: 394
# Song Goes: 60 and we guess: 67 at index: 395<---------
# Song Goes: gf0.0833 and we guess: gf0.0833 at index: 396
# Song Goes: 57 and we guess: 64 at index: 397<---------
# Song Goes: 69 and we guess: 76 at index: 398<---------
# Song Goes: gf0.25 and we guess: gf0.25 at index: 399

# %%
encoding=DF.iloc[0,2]
sequenceIn=[]

for word in encoding[:100]:
    sequenceIn.append(WordToNumber[word])
get_gf.predict(np.reshape(sequenceIn,(1,100,1))/len(vocab))

# %%
with open('SavedModels/just.testing.pickle','rb') as file:
    trialIn=pickle.load(file)

# %%
get_gf.predict(np.reshape(trialIn,(1,100,1))/len(vocab))
